# %% [markdown]
# # Python Data Cleaning Project
# This project using Python in Jupyter Notebooks showcases my data cleaning abilities in Python using Pandas.
#
# ## Step 1: Imports
# This step ensures my CSV file is imported correctly and can be read in my project.

# %%
#for GitHub - use Kaggle dataset instead of local file path

import pandas as pd
df = pd.read_csv("/Users/ethanm/Desktop/Python-data-cleaning-project/data/Messy_Employee_dataset.csv")
print(df.head())
print(df.info())
# Out:
#   Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0     EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1     EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2     EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3     EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4     EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
#
#     Join_Date     Salary                       Email       Phone  \
# 0    4/2/2021   59767.65       bob.davis@example.com -1651623197
# 1   7/10/2020   65304.66       bob.brown@example.com -1898471390
# 2   12/7/2023   88145.90     alice.jones@example.com -5596363211
# 3  11/27/2021   69450.99       eva.davis@example.com -3476490784
# 4    1/5/2022  109324.61  frank.williams@example.com -1586734256
#
#   Performance_Score  Remote_Work
# 0           Average         True
# 1         Excellent         True
# 2              Good         True
# ...

# %% [markdown]
# ## Step 2: Initial understanding of dataset
# There are null values in the Age and Salary columns, which are the **quantitative** data entries for this dataset. I should treat these null values in accordance with the business requirements for this piece of analysis.
# Depending on the reason for analysis, the data cleaning process could either:
# - leave these values as they are
# - impute the mean or median
# - remove all rows containing nulls

# %% [markdown]
# ## Step 3: Data Cleaning
#
# - [x] Drop duplicates (drop rows we don't need)
# - [x] Drop columns we don't need (for now I want to keep all the columns)
# - [x] Split Department_Region column into Department and Region
# - [x] Format Phone column for making international calls, i.e. +1 (xxx) xxx-xxxx, this requires string parsing
# - [ ] Check what we can't see (e.g. employee_ID is formatted correctly) - strip non-alphabet characters/non-numbers for each column as relevant
# - N.B.: .str.replace('[^a-zA-Z0-9]', '') will replace everything that's NOT in that list (the ^ = not) with nothing

# %%
df = df.drop_duplicates()
df
# Out:
#      Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0        EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1        EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2        EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3        EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
# ...          ...        ...       ...   ...                 ...       ...
# 1015     EMP2015      David    Miller  30.0       HR-California    Active
# 1016     EMP2016      David   Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017    Charlie  Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice    Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019      Heidi     Jones  30.0     DevOps-Illinois   Pending
#
#        Join_Date     Salary                         Email       Phone  \
# ...

# %% [markdown]
# Getting rid of characters we don't want - column by column

# %%
#Employee_ID
#df["Employee_ID"] = df["Employee_ID"].str.replace('^a-zA-Z-0-9', '')

# %%
#First_Name
#df["First_Name"] = df["First_Name"].str.replace('^a-zA-Z', '')

#Last_Name
#df["Last_Name"] = df["Last_Name"].str.replace('^a-zA-Z', '')

#Age - doesn't need anything, it's already a float column

#Department_Region -> we need to find out if there are any special characters in this column other than the hyphen
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 8
#       1 #First_Name
#       2 #df["First_Name"] = df["First_Name"].str.replace('^a-zA-Z', '')
#       3
#    (...)
#       6
#       7 #Age
# ----> 8 df["Age"].str.replace('^0-9', '')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...

# %%
#df[["Department", "Region"]] = df["Department_Region"].str.split('-', expand=True)
#df
#This creates new columns at the end of the dataframe called Department and Region.
# Out:
#      Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0        EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1        EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2        EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3        EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
# ...          ...        ...       ...   ...                 ...       ...
# 1015     EMP2015      David    Miller  30.0       HR-California    Active
# 1016     EMP2016      David   Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017    Charlie  Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice    Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019      Heidi     Jones  30.0     DevOps-Illinois   Pending
#
#        Join_Date     Salary                         Email       Phone  \
# ...

# %% [markdown]
# # DO NOT RUN THE CELL BELOW!

# %%
#df["Phone"] = df["Phone"].map(str).str.strip("-")
#df
#from here, get rid of any characters that are not 1-9


#String Parsing
#df["Phone"] = df["Phone"].apply(lambda x: "+1 (" + x[0:3] + ") " + x[3:6] + "-" + x[6:10])
#df["Phone"]
# Out:
# 0       +1 (165) 162-3197
# 1       +1 (189) 847-1390
# 2       +1 (559) 636-3211
# 3       +1 (347) 649-0784
# 4       +1 (158) 673-4256
#               ...
# 1015    +1 (354) 621-2759
# 1016    +1 (250) 826-1122
# 1017    +1 (126) 163-2487
# 1018    +1 (899) 572-9892
# 1019    +1 (762) 974-5492
# Name: Phone, Length: 1020, dtype: object

# %% [markdown]
# ## Step 4: Check everything
